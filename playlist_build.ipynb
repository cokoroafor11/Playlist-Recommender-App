# %% [markdown]
# <a href="https://colab.research.google.com/github/cokoroafor11/Playlist-Recommender-App/blob/main/playlist_build.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy --upgrade
# !pip install gdown
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
from google.colab import files
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (4.5.5)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.26.15)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
def excel_list_to_df(file):
    '''Create the dataframe from the excel sheet of playlists'''

    df = pd.read_excel(file, skiprows = 1)
    #playlists = df['Link']
    return df

# %%
# !gdown 'https://docs.google.com/uc?id=1yssmW3MTXSKwmnwZMItBBFdGsVsxAR4E&export=download'
editorial_df = excel_list_to_df('/content/Spotify Playlists - Editorial.xlsx')
# Out:
# Downloading...
# From: https://docs.google.com/uc?id=1yssmW3MTXSKwmnwZMItBBFdGsVsxAR4E&export=download
# To: /content/Spotify Playlists - Editorial.xlsx
# 100% 2.58M/2.58M [00:00<00:00, 170MB/s]

# %% [markdown]
# ## Cleaning Up and Combining DataFrames

# %%
editorial_df
# Out:
#                         Playlist Country                               Genres  \
# 0               Today's Top Hits     NaN             Pop,R&B/Soul,Hip-Hop/Rap
# 1                      RapCaviar      US                      Hip-Hop/Rap,Pop
# 2                    Viva Latino     NaN  Latin,Latin Hip-Hop/Rap,Hip-Hop/Rap
# 3                  Rock Classics      US                 Rock,Pop,Alternative
# 4                Baila Reggaeton      AR    Latin,Latin Hip-Hop/Rap,Latin Pop
# ...                          ...     ...                                  ...
# 14995                    Rockbus     NaN          Alternative,Rock,Indie Rock
# 14996  12" Smashes - Winter 1987     NaN                    Pop,R&B/Soul,Rock
# 14997         Christmas Shopping     NaN                     Pop,Holiday,Rock
# 14998        Toots & The Maytals     NaN                 Reggae,Rock,R&B/Soul
# 14999    La St-valentin par ELLE     NaN                       Pop,Vocal,Rock
#
#                    Curator Followers 28-Day Change  28-Day Add Personalized  \
# 0                  Spotify    33.69M        147942        1.00           No
# 1                  Spotify    15.32M         74925        1.00           No
# 2                  Spotify     13.8M        118931        1.00           No
# 3                  Spotify    11.54M         49347        0.67           No
# 4                  Spotify    10.94M         21300        1.00           No
# ...                    ...       ...           ...         ...          ...
# 14995  Spotify Deutschland        14             0        0.00           No
# 14996              Spotify        14             0        0.00           No
# 14997  Spotify Philippines        14             0        0.00           No
# 14998              Spotify        14             0        0.00           No
# 14999       Spotify France        14             0        0.00           No
#
#        Track Age     Playlist Updated Playlist ID  \
# 0      frontline  2023-05-20 00:00:00     1645080
# 1      frontline  2023-05-22 00:00:00      848051
# 2      frontline  2023-05-19 00:00:00     1645077
# 3      catalogue  2023-05-20 00:00:00     1644653
# 4      frontline  2023-05-19 00:00:00     1015841
# ...          ...                  ...         ...
# 14995  catalogue  2021-04-09 00:00:00     2099193
# 14996  catalogue  2021-04-09 00:00:00     2112347
# 14997  catalogue  2022-11-08 00:00:00     2117901
# 14998  catalogue  2023-05-20 00:00:00     2118562
# 14999  catalogue  2021-04-09 00:00:00     2121771
#
#                        Playlist Url     Spotify Playlist ID  \
# 0      /playlist/spotify?id=1645080  37i9dQZF1DXcBWIGoYBM5M
# 1       /playlist/spotify?id=848051  37i9dQZF1DX0XUsuxWHRQd
# 2      /playlist/spotify?id=1645077  37i9dQZF1DX10zKzsJ2jva
# 3      /playlist/spotify?id=1644653  37i9dQZF1DWXRqgorJj26U
# 4      /playlist/spotify?id=1015841  37i9dQZF1DWY7IeIP1cdjF
# ...                             ...                     ...
# 14995  /playlist/spotify?id=2099193  3FHNR9ijnE6O8cHpttn3h8
# 14996  /playlist/spotify?id=2112347  4B2flPTw4D6i8Uoq4zMRZ4
# 14997  /playlist/spotify?id=2117901  6E82eKCXSkR2zWkLwGEaoo
# 14998  /playlist/spotify?id=2118562  37i9dQZF1EF3jdeKRkMFDl
# 14999  /playlist/spotify?id=2121771  69iwTzDx1DCfaPmwWV93SX
#
#                                     Spotify Playlist URL  Unnamed: 14  \
# 0      https://open.spotify.com/user/spotify/playlist...          NaN
# 1      https://open.spotify.com/user/spotify/playlist...          NaN
# 2      https://open.spotify.com/user/spotify/playlist...          NaN
# 3      https://open.spotify.com/user/spotify/playlist...          NaN
# 4      https://open.spotify.com/user/spotify/playlist...          NaN
# ...                                                  ...          ...
# 14995  https://open.spotify.com/user/spotify_germany/...     132977.0
# 14996  https://open.spotify.com/user/spotify/playlist...          2.0
# 14997  https://open.spotify.com/user/spotifyphilippin...     133035.0
# 14998  https://open.spotify.com/user/spotify/playlist...          2.0
# 14999  https://open.spotify.com/user/spotify_france/p...     132976.0
#
#                        Curator URL  Spotify Curator ID  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# ...                            ...                 ...
# 14995  /curator/spotify?id=2099193     spotify_germany
# 14996  /curator/spotify?id=2112347             spotify
# 14997  /curator/spotify?id=2117901  spotifyphilippines
# 14998  /curator/spotify?id=2118562             spotify
# 14999  /curator/spotify?id=2121771      spotify_france
#
#                                     Spotify Curator URL
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 14995     https://open.spotify.com/user/spotify_germany
# 14996             https://open.spotify.com/user/spotify
# 14997  https://open.spotify.com/user/spotifyphilippines
# 14998             https://open.spotify.com/user/spotify
# 14999      https://open.spotify.com/user/spotify_france
#
# [15000 rows x 18 columns]

# %%
# !gdown 'https://docs.google.com/uc?id=1WrcHWrIEHJ8b5t1yAcaFJj_9Z8I3VRrq&export=download'
independent_df = excel_list_to_df('/content/Spotify Playlists - Popular Independent Creators.xlsx')
# Out:
# Downloading...
# From: https://docs.google.com/uc?id=1WrcHWrIEHJ8b5t1yAcaFJj_9Z8I3VRrq&export=download
# To: /content/Spotify Playlists - Popular Independent Creators.xlsx
# 100% 4.97M/4.97M [00:00<00:00, 20.4MB/s]

# %%
independent_df
# Out:
#                                                 Playlist Country  \
# 0      Lofi Fruits Music - lofi hip hop beats to stud...     NaN
# 1                                           Study lofi 📚     NaN
# 2      Dance Fruits Music - dance music to workout, g...     NaN
# 3                                        Deep House 2023     NaN
# 4      Deep House - dance music to workout, game & pa...     NaN
# ...                                                  ...     ...
# 22090                                     Vax'ildan 2016     NaN
# 22091                   Electrónica Cristiana 2023 Latin     NaN
# 22092                           Middle Ground - Maroon 5     NaN
# 22093  Young Royals Soundtrack • Netflix 2022 • Seaso...     NaN
# 22094                             Gothic/Symphonic Metal     NaN
#
#                                      Genres               Curator Followers  \
# 0           Easy Listening,Pop,Instrumental          Fruits Music     7.79M
# 1      Hip-Hop/Rap,Instrumental,Alternative             Lofi Girl     7.06M
# 2                      Dance,Electronic,Pop          Fruits Music     5.41M
# 3                    Dance,House,Electronic             Selected.      5.2M
# 4                      Dance,Electronic,Pop          Fruits Music     3.17M
# ...                                     ...                   ...       ...
# 22090                  Alternative,Pop,Rock         geekandsundry     4.72K
# 22091            Dance,Christian,Electronic  Carlos Herrera Music     4.71K
# 22092                 Dance,Pop,Hip-Hop/Rap      Carmen Gutiérrez     4.71K
# 22093            Pop,Alternative,Electronic           Retro Tones     4.71K
# 22094                  Rock,Metal,Hard Rock      Bengan Bengtsson     4.71K
#
#       28-Day Change  28-Day Add Personalized  Track Age     Playlist Updated  \
# 0             38658       1.000           No      mixed  2023-05-13 00:00:00
# 1             18771       1.000           No      mixed  2023-05-22 00:00:00
# 2             62720       0.991           No  frontline  2023-05-20 00:00:00
# 3             64715       0.968           No  frontline  2023-05-20 00:00:00
# 4            -35265       0.991           No  frontline  2023-05-19 00:00:00
# ...             ...         ...          ...        ...                  ...
# 22090             1       0.000           No  catalogue  2021-04-06 00:00:00
# 22091           179       0.027           No      mixed  2023-05-20 00:00:00
# 22092            37       1.000           No  catalogue  2023-05-19 00:00:00
# 22093            34       0.000           No  catalogue  2022-12-10 00:00:00
# 22094            -5       0.000           No  catalogue  2021-04-06 00:00:00
#
#       Playlist ID                   Playlist Url     Spotify Playlist ID  \
# 0         1842049   /playlist/spotify?id=1842049  3LFIBdP7eZXJKqf3guepZ1
# 1         1870135   /playlist/spotify?id=1870135  0vvXsWCC9xrXsKd4FyS8kM
# 2         1662638   /playlist/spotify?id=1662638  6xGLprv9fmlMgeAMpW0x51
# 3         1967705   /playlist/spotify?id=1967705  6vDGVr652ztNWKZuHvsFvx
# 4        14967885  /playlist/spotify?id=14967885  4EjIhZWbxJNNiHPwVh17mF
# ...           ...                            ...                     ...
# 22090     1982199   /playlist/spotify?id=1982199  377n9mEjMGFfzT3hVnVgca
# 22091     1872749   /playlist/spotify?id=1872749  563J6xdeKsjQIHuTMIUhRh
# 22092     2807959   /playlist/spotify?id=2807959  76aX3Y6FXyYavwAdIAwEVv
# 22093     4982947   /playlist/spotify?id=4982947  0mJAlzQ69VXLRHg8zbv9X3
# 22094       65014     /playlist/spotify?id=65014  0UGcJQGQw2IIBiE5Ce8HGE
#
#                                     Spotify Playlist URL  \
# 0      https://open.spotify.com/user/a902190/playlist...
# 1      https://open.spotify.com/user/chilledcow/playl...
# 2      https://open.spotify.com/user/a902190/playlist...
# 3      https://open.spotify.com/user/selectedbase/pla...
# 4      https://open.spotify.com/user/a902190/playlist...
# ...                                                  ...
# 22090  https://open.spotify.com/user/geekandsundry/pl...
# 22091  https://open.spotify.com/user/carlosrherrera/p...
# 22092  https://open.spotify.com/user/klrco2bjh3jmuyj8...
# 22093  https://open.spotify.com/user/o16a7ny37b9026px...
# 22094  https://open.spotify.com/user/beengan/playlist...
#
#       playlistTable.CuratorId                   Curator URL  \
# 0                       53142   /curator/spotify?id=1842049
# 1                      231899   /curator/spotify?id=1870135
# 2                       53142   /curator/spotify?id=1662638
# 3                      129628   /curator/spotify?id=1967705
# 4                       53142  /curator/spotify?id=14967885
# ...                       ...                           ...
# 22090                  229617   /curator/spotify?id=1982199
# 22091                  271352   /curator/spotify?id=1872749
# 22092                  276956   /curator/spotify?id=2807959
# 22093                 8235712   /curator/spotify?id=4982947
# 22094                   61838     /curator/spotify?id=65014
#
#               Spotify Curator ID  \
# 0                        a902190
# 1                     chilledcow
# 2                        a902190
# 3                   selectedbase
# 4                        a902190
# ...                          ...
# 22090              geekandsundry
# 22091             carlosrherrera
# 22092  klrco2bjh3jmuyj827k43hz9z
# 22093  o16a7ny37b9026pxfoqc4rhe1
# 22094                    beengan
#
#                                      Spotify Curator URL
# 0                  https://open.spotify.com/user/a902190
# 1               https://open.spotify.com/user/chilledcow
# 2                  https://open.spotify.com/user/a902190
# 3             https://open.spotify.com/user/selectedbase
# 4                  https://open.spotify.com/user/a902190
# ...                                                  ...
# 22090        https://open.spotify.com/user/geekandsundry
# 22091       https://open.spotify.com/user/carlosrherrera
# 22092  https://open.spotify.com/user/klrco2bjh3jmuyj8...
# 22093  https://open.spotify.com/user/o16a7ny37b9026px...
# 22094              https://open.spotify.com/user/beengan
#
# [22095 rows x 18 columns]
# Warning: total number of rows (22095) exceeds max_rows (20000). Limiting to first (20000) rows.

# %% [markdown]
# Things to Do
# 1. Drop unnecessary columns
# 2. Dorp Na
# 3. Remove playlists under a certain amount of followers
# 4. Join the dataframes

# %%
#Editorial
editorial_df_cleaned = editorial_df[['Playlist','Genres','Followers','Spotify Playlist URL']]

# %%
editorial_df_cleaned.dtypes
# Out:
# Playlist                object
# Genres                  object
# Followers               object
# Spotify Playlist URL    object
# dtype: object

# %%
#Function to convert numbers: i.e. 10k to 10,000
#Shoutout github: https://stackoverflow.com/questions/39684548/convert-the-string-2-90k-to-2900-or-5-2m-to-5200000-in-pandas-dataframe
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x or 'k' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x or 'm' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x or 'b' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

# %%
editorial_df_cleaned['Followers'] = editorial_df_cleaned['Followers'].apply(value_to_float)
editorial_df_cleaned['Followers'] = editorial_df_cleaned['Followers'].astype('int')
# Out:
# <ipython-input-20-f3b95cca01a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   editorial_df_cleaned['Followers'] = editorial_df_cleaned['Followers'].apply(value_to_float)
# <ipython-input-20-f3b95cca01a2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   editorial_df_cleaned['Followers'] = editorial_df_cleaned['Followers'].astype('int')

# %%
editorial_df_cleaned = editorial_df_cleaned[editorial_df_cleaned['Followers'] > 5000]

# %%
editorial_df_cleaned
# Out:
#                       Playlist                               Genres  \
# 0             Today's Top Hits             Pop,R&B/Soul,Hip-Hop/Rap
# 1                    RapCaviar                      Hip-Hop/Rap,Pop
# 2                  Viva Latino  Latin,Latin Hip-Hop/Rap,Hip-Hop/Rap
# 3                Rock Classics                 Rock,Pop,Alternative
# 4              Baila Reggaeton    Latin,Latin Hip-Hop/Rap,Latin Pop
# ...                        ...                                  ...
# 6309      Top Hits España 2004                 Pop,Rock,Hip-Hop/Rap
# 6310                HOUSE HYPE               Dance,Electronic,House
# 6311  Lofi Beats: Best of 2022  Hip-Hop/Rap,Instrumental,Electronic
# 6312       Latin Dance Workout                  Latin Pop,Latin,Pop
# 6313       Fresh Finds SG & MY             Pop,R&B/Soul,Alternative
#
#       Followers                               Spotify Playlist URL
# 0      33690000  https://open.spotify.com/user/spotify/playlist...
# 1      15320000  https://open.spotify.com/user/spotify/playlist...
# 2      13800000  https://open.spotify.com/user/spotify/playlist...
# 3      11540000  https://open.spotify.com/user/spotify/playlist...
# 4      10940000  https://open.spotify.com/user/spotify/playlist...
# ...         ...                                                ...
# 6309       5020  https://open.spotify.com/user/spotify/playlist...
# 6310       5010  https://open.spotify.com/user/spotify/playlist...
# 6311       5010  https://open.spotify.com/user/spotify/playlist...
# 6312       5010  https://open.spotify.com/user/spotify/playlist...
# 6313       5010  https://open.spotify.com/user/spotify/playlist...
#
# [6313 rows x 4 columns]

# %%
independent_df_cleaned = independent_df[['Playlist','Genres','Followers','Spotify Playlist URL']]

# %%
independent_df_cleaned.dtypes
# Out:
# Playlist                object
# Genres                  object
# Followers               object
# Spotify Playlist URL    object
# dtype: object

# %%
independent_df_cleaned['Followers'] = independent_df_cleaned['Followers'].apply(value_to_float)
independent_df_cleaned['Followers'] = independent_df_cleaned['Followers'].astype('int')
# Out:
# <ipython-input-27-a31634495683>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   independent_df_cleaned['Followers'] = independent_df_cleaned['Followers'].apply(value_to_float)
# <ipython-input-27-a31634495683>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   independent_df_cleaned['Followers'] = independent_df_cleaned['Followers'].astype('int')

# %%
independent_df_cleaned = independent_df_cleaned[independent_df_cleaned['Followers'] > 5000]

# %%
independent_df_cleaned
# Out:
#                                                 Playlist  \
# 0      Lofi Fruits Music - lofi hip hop beats to stud...
# 1                                           Study lofi 📚
# 2      Dance Fruits Music - dance music to workout, g...
# 3                                        Deep House 2023
# 4      Deep House - dance music to workout, game & pa...
# ...                                                  ...
# 21103                                   Unnamed Playlist
# 21104            Lord Of Portland - best stuff from home
# 21105                              Kate Tempest Complete
# 21106                         Pop & Dance Mixed Feelings
# 21107                                       Secret Sauce
#
#                                      Genres  Followers  \
# 0           Easy Listening,Pop,Instrumental    7790000
# 1      Hip-Hop/Rap,Instrumental,Alternative    7060000
# 2                      Dance,Electronic,Pop    5410000
# 3                    Dance,House,Electronic    5200000
# 4                      Dance,Electronic,Pop    3170000
# ...                                     ...        ...
# 21103                     R&B/Soul,Pop,Rock       5010
# 21104                  Rock,Alternative,Pop       5010
# 21105         Hip-Hop/Rap,Spoken Word,Dance       5010
# 21106                  Pop,Dance,Electronic       5010
# 21107                Dance,House,Electronic       5010
#
#                                     Spotify Playlist URL
# 0      https://open.spotify.com/user/a902190/playlist...
# 1      https://open.spotify.com/user/chilledcow/playl...
# 2      https://open.spotify.com/user/a902190/playlist...
# 3      https://open.spotify.com/user/selectedbase/pla...
# 4      https://open.spotify.com/user/a902190/playlist...
# ...                                                  ...
# 21103  https://open.spotify.com/user/g0u1d1e1/playlis...
# 21104  https://open.spotify.com/user/myfearofmusic/pl...
# 21105  https://open.spotify.com/user/katetempestoffic...
# 21106  https://open.spotify.com/user/7j0vrvnrrh8t9rz2...
# 21107  https://open.spotify.com/user/pinnaclecollecti...
#
# [21106 rows x 4 columns]

# %%
#Merge dfs together
all_playlist_df = pd.concat([editorial_df_cleaned,independent_df_cleaned])

# %%
all_playlist_df
# Out:
#                                       Playlist  \
# 0                             Today's Top Hits
# 1                                    RapCaviar
# 2                                  Viva Latino
# 3                                Rock Classics
# 4                              Baila Reggaeton
# ...                                        ...
# 21103                         Unnamed Playlist
# 21104  Lord Of Portland - best stuff from home
# 21105                    Kate Tempest Complete
# 21106               Pop & Dance Mixed Feelings
# 21107                             Secret Sauce
#
#                                     Genres  Followers  \
# 0                 Pop,R&B/Soul,Hip-Hop/Rap   33690000
# 1                          Hip-Hop/Rap,Pop   15320000
# 2      Latin,Latin Hip-Hop/Rap,Hip-Hop/Rap   13800000
# 3                     Rock,Pop,Alternative   11540000
# 4        Latin,Latin Hip-Hop/Rap,Latin Pop   10940000
# ...                                    ...        ...
# 21103                    R&B/Soul,Pop,Rock       5010
# 21104                 Rock,Alternative,Pop       5010
# 21105        Hip-Hop/Rap,Spoken Word,Dance       5010
# 21106                 Pop,Dance,Electronic       5010
# 21107               Dance,House,Electronic       5010
#
#                                     Spotify Playlist URL
# 0      https://open.spotify.com/user/spotify/playlist...
# 1      https://open.spotify.com/user/spotify/playlist...
# 2      https://open.spotify.com/user/spotify/playlist...
# 3      https://open.spotify.com/user/spotify/playlist...
# 4      https://open.spotify.com/user/spotify/playlist...
# ...                                                  ...
# 21103  https://open.spotify.com/user/g0u1d1e1/playlis...
# 21104  https://open.spotify.com/user/myfearofmusic/pl...
# 21105  https://open.spotify.com/user/katetempestoffic...
# 21106  https://open.spotify.com/user/7j0vrvnrrh8t9rz2...
# 21107  https://open.spotify.com/user/pinnaclecollecti...
#
# [27419 rows x 4 columns]

# %%
#Download csv of all playlists
all_playlist_df.to_excel('all_spotify_playlists.xlsx')
files.download('all_spotify_playlists.xlsx')
